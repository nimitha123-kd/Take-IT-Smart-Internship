# %% [markdown]
# <a href="https://colab.research.google.com/github/nimitha123-kd/Take-IT-Smart-Internship/blob/main/Brain_Tumor_Dection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("navoneel/brain-mri-images-for-brain-tumor-detection")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'brain-mri-images-for-brain-tumor-detection' dataset.
# Path to dataset files: /kaggle/input/brain-mri-images-for-brain-tumor-detection

# %% [markdown]
# **List all sub directories inside main folder**

# %%
import os
print(os.listdir(path))
# Out:
# ['no', 'yes', 'brain_tumor_dataset']

# %% [markdown]
# **Display 5 images in each folder**

# %%
import matplotlib.pyplot as plt
from PIL import Image
i=1
for class_name in os.listdir(path):
  class_path = os.path.join(path,class_name)

  if os.path.isdir(class_path):
    images = os.listdir(class_path)[:5]# 0 to 5 images in each row.

# Inoder to get path,folder & image all together....
    for img in images:
      img_path = os.path.join(class_path,img)

# Inoder to get the the images open , and visualized.
      if os.path.isfile(img_path):
        img= Image.open(img_path)
        plt.subplot(2,5,i) # 2 rows , 5 images in each row.
        plt.imshow(img)
        plt.title(class_name)
        plt.axis('off')
        i+=1
plt.tight_layout()
plt.show()

# %%
# Just running the above programme part by part , for better understanding.

# %%
#path for every folder
for class_name in os.listdir(path): # each subfolder in the main folder is considered as the clss_name.
  class_path = os.path.join(path,class_name)# join the original path with each class_name.
  print(class_path)
# Out:
# /kaggle/input/brain-mri-images-for-brain-tumor-detection/no
# /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes
# /kaggle/input/brain-mri-images-for-brain-tumor-detection/brain_tumor_dataset

# %%
# To see how many images are there...
import matplotlib.pyplot as plt
from PIL import Image

for class_name in os.listdir(path):
  class_path = os.path.join(path,class_name)

  if os.path.isdir(class_path):
    images = os.listdir(class_path)
    print(images)
# Out:
# ['34 no.jpg', 'N20.JPG', 'N1.JPG', '49 no.jpg', 'N15.jpg', 'No18.jpg', '31 no.jpg', 'no 6.jpg', '3 no.jpg', 'no 5.jpeg', 'no 1.jpg', '26 no.jpg', 'N26.JPG', 'N5.jpg', '6 no.jpg', 'No21.jpg', '17 no.jpg', 'No22.jpg', '29 no.jpg', '46 no.jpg', '32 no.jpg', '42 no.jpg', 'no 90.jpg', 'no 94.jpg', 'No19.jpg', '47 no.jpg', 'N22.JPG', 'No12.jpg', '15 no.jpg', '20 no.jpg', 'No13.jpg', '11 no.jpg', 'N11.jpg', 'No17.jpg', 'no 98.jpg', '18 no.jpg', 'N19.JPG', '25 no.jpg', '24 no.jpg', 'no 91.jpeg', '45 no.jpg', '22 no.jpg', 'No16.jpg', '44no.jpg', '4 no.jpg', '36 no.jpg', '8 no.jpg', '48 no.jpeg', 'No20.jpg', 'no 2.jpg', 'no 10.jpg', '7 no.jpg', '10 no.jpg', 'N17.jpg', '14 no.jpg', 'no 8.jpg', '38 no.jpg', '40 no.jpg', 'no 9.png', 'N3.jpg', 'no 89.jpg', '19 no.jpg', '12 no.jpg', 'N2.JPG', 'No11.jpg', 'no 92.jpg', 'No14.jpg', '39 no.jpg', 'no 7.jpeg', '27 no.jpg', '5 no.jpg', 'no 95.jpg', 'no.jpg', 'no 3.jpg', 'No15.jpg', 'no 923.jpg', '28 no.jpg', 'no 100.jpg', '23 no.jpg', '13 no.jpg', '37 no.jpg', '21 no.jpg', '30 no.jpg', 'no 4.jpg', '9 no.jpg', 'no 99.jpg', 'N21.jpg', '50 no.jpg', '43 no.jpg', 'no 96.jpg', '41 no.jpg', 'N16.jpg', 'no 97.jpg', '1 no.jpeg', '2 no.jpeg', '35 no.jpg', 'N6.jpg', '33 no.jpg']
# ['no', 'yes']

# %%
import matplotlib.pyplot as plt
from PIL import Image
i=1
for class_name in os.listdir(path):
  class_path = os.path.join(path,class_name)

  if os.path.isdir(class_path):
    images = os.listdir(class_path)[:5]# gives u 5 images in a row.

# Inoder to get path,folder & image all together....
    for img in images:
      img_path = os.path.join(class_path,img)
      print(img_path)
# Out:
# /kaggle/input/brain-mri-images-for-brain-tumor-detection/no/34 no.jpg
# /kaggle/input/brain-mri-images-for-brain-tumor-detection/no/N20.JPG
# /kaggle/input/brain-mri-images-for-brain-tumor-detection/no/N1.JPG
# /kaggle/input/brain-mri-images-for-brain-tumor-detection/no/49 no.jpg
# /kaggle/input/brain-mri-images-for-brain-tumor-detection/no/N15.jpg
# /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes/Y115.JPG
# /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes/Y192.JPG
# /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes/Y162.jpg
# /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes/Y9.jpg
# /kaggle/input/brain-mri-images-for-brain-tumor-detection/yes/Y108.jpg
# /kaggle/input/brain-mri-images-for-brain-tumor-detection/brain_tumor_dataset/no
# /kaggle/input/brain-mri-images-for-brain-tumor-detection/brain_tumor_dataset/yes

# %%
for class_name in os.listdir(path):
    class_path = os.path.join(path, class_name)
    count = len(os.listdir(class_path))
    print(count,'-->', class_name)
# Out:
# 98 --> no
# 155 --> yes
# 2 --> brain_tumor_dataset

# %% [markdown]
#  **create  a dataframe which includes img_path and label.**

# %%
# create a dataframe which includes img_path ,labels
import pandas as pd

data = []

for label in os.listdir(path):
    class_path = os.path.join(path, label)

    if os.path.isdir(class_path):
        for img in os.listdir(class_path):
            img_path = os.path.join(class_path, img)
            data.append([img_path, label])

df = pd.DataFrame(data, columns=["image_path", "label"])
df
# Out:
#                                             image_path                label
# 0    /kaggle/input/brain-mri-images-for-brain-tumor...                   no
# 1    /kaggle/input/brain-mri-images-for-brain-tumor...                   no
# 2    /kaggle/input/brain-mri-images-for-brain-tumor...                   no
# 3    /kaggle/input/brain-mri-images-for-brain-tumor...                   no
# 4    /kaggle/input/brain-mri-images-for-brain-tumor...                   no
# ..                                                 ...                  ...
# 250  /kaggle/input/brain-mri-images-for-brain-tumor...                  yes
# 251  /kaggle/input/brain-mri-images-for-brain-tumor...                  yes
# 252  /kaggle/input/brain-mri-images-for-brain-tumor...                  yes
# 253  /kaggle/input/brain-mri-images-for-brain-tumor...  brain_tumor_dataset
# 254  /kaggle/input/brain-mri-images-for-brain-tumor...  brain_tumor_dataset
#
# [255 rows x 2 columns]

# %% [markdown]
# # shuffle the images.

# %%
df = df.sample(frac=1,random_state=42).reset_index(drop=True)#frac=1 → selects 100% of the rows (i.e., the entire dataset, but shuffled if random_state is set).
df
# Out:
#                                             image_path label
# 0    /kaggle/input/brain-mri-images-for-brain-tumor...   yes
# 1    /kaggle/input/brain-mri-images-for-brain-tumor...    no
# 2    /kaggle/input/brain-mri-images-for-brain-tumor...    no
# 3    /kaggle/input/brain-mri-images-for-brain-tumor...   yes
# 4    /kaggle/input/brain-mri-images-for-brain-tumor...   yes
# ..                                                 ...   ...
# 250  /kaggle/input/brain-mri-images-for-brain-tumor...   yes
# 251  /kaggle/input/brain-mri-images-for-brain-tumor...    no
# 252  /kaggle/input/brain-mri-images-for-brain-tumor...    no
# 253  /kaggle/input/brain-mri-images-for-brain-tumor...   yes
# 254  /kaggle/input/brain-mri-images-for-brain-tumor...   yes
#
# [255 rows x 2 columns]

# %%
train_size = int(0.7 * len(data))
val_size = int(0.15 * len(data))
test_size = int(0.15*len(data))
print(f"train_size:{train_size} -----val_size:{val_size}----test_size:{test_size}")

train_data = df.iloc[:train_size]
# data.iloc[:,52500]
val_data =df.iloc[train_size:train_size + val_size]
# data.iloc[52500:52500+11250]
test_data = df.iloc[train_size + val_size:]
# data.iloc[52500+11250:]

# Display the sizes of each set
print(f'Training set size: {len(train_data)}')
print(f'Validation set size: {len(val_data)}')
print(f'Test set size: {len(test_data)}')
# Out:
# train_size:178 -----val_size:38----test_size:38
# Training set size: 178
# Validation set size: 38
# Test set size: 39

# %%
image_p = df["image_path"][0]
image = Image.open(image_p)
width, height = image.size
print(f"height,width:{height,width}")
# Out:
# height,width:(256, 256)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
batch_size = 32
img_height = 224
img_width = 224

# %%
# Normalization
data_generator = ImageDataGenerator(
    rescale=1.0/255, # Normalization: Pixel values go from 0–255 → 0–1
    rotation_range=40, #Randomly rotates image up to ±40 degrees
    width_shift_range=0.2, #Moves image left/right by 20%
    height_shift_range=0.2, # Moves image up/down by 20%
    shear_range=0.2, # Slants the image (like pushing it sideways)
    zoom_range=0.2, # Zoom in/out randomly
    horizontal_flip=True, #Flips image left ↔ right
    fill_mode='nearest' #This fills those gaps using nearest pixels
)

# %%
# train data
train_generator = data_generator.flow_from_dataframe(
  dataframe=train_data,
  x_col="image_path",
  y_col="label",
  target_size=(img_height, img_width),
  batch_size=batch_size,
  class_mode="categorical",
  shuffle=True,
  seed=42
)
# Out:
# Found 177 validated image filenames belonging to 2 classes.
# /usr/local/lib/python3.12/dist-packages/keras/src/legacy/preprocessing/image.py:918: UserWarning: Found 1 invalid image filename(s) in x_col="image_path". These filename(s) will be ignored.
#   warnings.warn(

# %%
# test generator
test_generator = data_generator.flow_from_dataframe(
  dataframe=test_data,
  x_col="image_path",
  y_col="label",
  target_size=(img_height, img_width),
  batch_size=batch_size,
  class_mode="categorical",
  shuffle=True,
  seed=42
)
# Out:
# Found 38 validated image filenames belonging to 2 classes.
# /usr/local/lib/python3.12/dist-packages/keras/src/legacy/preprocessing/image.py:918: UserWarning: Found 1 invalid image filename(s) in x_col="image_path". These filename(s) will be ignored.
#   warnings.warn(

# %%
# validation generator
validation_generator = data_generator.flow_from_dataframe(
  dataframe=val_data,
  x_col="image_path",
  y_col="label",
  target_size=(img_height, img_width),
  batch_size=batch_size,
  class_mode="categorical",
  shuffle=True,
  seed=42
)
# Out:
# Found 38 validated image filenames belonging to 2 classes.

# %%
for image_batch, labels_batch in train_generator:
    print(f"Train Shape: {image_batch.shape} (Batches = {len(train_generator)})")
    print(f"Train Label Shape: {labels_batch.shape}\n")
    break

for image_batch, labels_batch in validation_generator:
    print(f"Validation Shape: {image_batch.shape} (Batches = {len(validation_generator)})")
    print(f"Validation Label Shape: {labels_batch.shape}\n")
    break

for image_batch, labels_batch in test_generator:
    print(f"Test Shape: {image_batch.shape} (Batches = {len(test_generator)})")
    print(f"Test Label Shape: {labels_batch.shape}\n")
    break
# Out:
# Train Shape: (32, 224, 224, 3) (Batches = 6)
# Train Label Shape: (32, 2)
#
# Validation Shape: (32, 224, 224, 3) (Batches = 2)
# Validation Label Shape: (32, 2)
#
# Test Shape: (32, 224, 224, 3) (Batches = 2)
# Test Label Shape: (32, 2)

# %%
from tensorflow.keras import layers,models
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import binary_crossentropy

# %%
n_classes= 2
cnn_model = models.Sequential([
    layers.Input(shape=(224,224,3)),
    layers.Conv2D(32,kernel_size= (3,3),activation='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64,kernel_size= (3,3),activation='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64,kernel_size= (3,3),activation='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64,kernel_size= (3,3),activation='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Flatten(),
    layers.Dense(64,activation='relu'),
    layers.Dense(n_classes,activation='sigmoid')])

# %%
cnn_model.compile(loss=binary_crossentropy,
                  optimizer=Adam(),
                  metrics=['accuracy'])

# %%
Cnn = cnn_model.fit(train_generator,
                    epochs=100,validation_data=validation_generator,
                    verbose=1)
# Out:
# Epoch 1/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 16s 2s/step - accuracy: 0.6102 - loss: 0.6679 - val_accuracy: 0.6053 - val_loss: 0.6462
# Epoch 2/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.6102 - loss: 0.6334 - val_accuracy: 0.6053 - val_loss: 0.6497
# Epoch 3/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.6384 - loss: 0.6574 - val_accuracy: 0.6316 - val_loss: 0.6239
# Epoch 4/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.6215 - loss: 0.6414 - val_accuracy: 0.6579 - val_loss: 0.6293
# Epoch 5/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.
# Epoch 44/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.7627 - loss: 0.5298 - val_accuracy: 0.8684 - val_loss: 0.3915
# Epoch 45/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.7288 - loss: 0.5686 - val_accuracy: 0.8158 - val_loss: 0.4943
# Epoch 46/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.7401 - loss: 0.5485 - val_accuracy: 0.7105 - val_loss: 0.5696
# Epoch 47/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.7571 - loss: 0.5239 - val_accuracy: 0.8684 - val_loss: 0.3996
# Epoch 48/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.7571 - loss: 0.5021 - val_accuracy: 0.7105 - val_loss: 0.4602
# Epoch 49/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.8023 - loss: 0.4855 - val_accuracy: 0.8421 - val_loss: 0.4347
# Epoch 50/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 15s 2s/step - accuracy: 0.7853 - loss: 0.4606 - val_accuracy: 0.7368 - val_loss: 0.5137
# Epoch 51/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 18s 2s/step - accuracy: 0.7797 - loss: 0.4777 - val_accuracy: 0.8421 - val_loss: 0.3567
# Epoch 52/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.7458 - loss: 0.5220 - val_accuracy: 0.7895 - val_loss: 0.5212
# Epoch 53/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.7684 - loss: 0.5004 - val_accuracy: 0.7632 - val_loss: 0.4902
# Epoch 54/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.7684 - loss: 0.4858 - val_accuracy: 0.8158 - val_loss: 0.4235
# Epoch 55/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - accuracy: 0.7684 - loss: 0.4991 - val_accuracy: 0.8684 - val_loss: 0.3718
# Epoch 56/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.7797 - loss: 0.4698 - val_accuracy: 0.8947 - val_loss: 0.3256
# Epoch 57/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.7797 - loss: 0.5021 - val_accuracy: 0.7632 - val_loss: 0.4814
# Epoch 58/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.7458 - loss: 0.5221 - val_accuracy: 0.8684 - val_loss: 0.4236
# Epoch 59/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.7514 - loss: 0.5018 - val_accuracy: 0.8421 - val_loss: 0.4168
# Epoch 60/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.7910 - loss: 0.4760 - val_accuracy: 0.7632 - val_loss: 0.4211
# Epoch 61/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.8305 - loss: 0.4512 - val_accuracy: 0.8158 - val_loss: 0.5086
# Epoch 62/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.7514 - loss: 0.5295 - val_accuracy: 0.7105 - val_loss: 0.4497
# Epoch 63/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.7684 - loss: 0.4896 - val_accuracy: 0.7895 - val_loss: 0.4973
# Epoch 64/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.7740 - loss: 0.4928 - val_accuracy: 0.7632 - val_loss: 0.5216
# Epoch 65/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - accuracy: 0.7627 - loss: 0.4795 - val_accuracy: 0.8158 - val_loss: 0.4310
# Epoch 66/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 14s 3s/step - accuracy: 0.7966 - loss: 0.4673 - val_accuracy: 0.7632 - val_loss: 0.4279
# Epoch 67/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.8023 - loss: 0.4300 - val_accuracy: 0.8684 - val_loss: 0.3275
# Epoch 68/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.7910 - loss: 0.5050 - val_accuracy: 0.7632 - val_loss: 0.6021
# Epoch 69/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.7232 - loss: 0.5527 - val_accuracy: 0.8158 - val_loss: 0.4832
# Epoch 70/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.7514 - loss: 0.5354 - val_accuracy: 0.7632 - val_loss: 0.4965
# Epoch 71/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.7627 - loss: 0.4910 - val_accuracy: 0.7632 - val_loss: 0.4828
# Epoch 72/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.7966 - loss: 0.4773 - val_accuracy: 0.7105 - val_loss: 0.4683
# Epoch 73/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 13s 2s/step - accuracy: 0.7797 - loss: 0.4974 - val_accuracy: 0.8421 - val_loss: 0.3838
# Epoch 74/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 14s 2s/step - accuracy: 0.7740 - loss: 0.4923 - val_accuracy: 0.7895 - val_loss: 0.4377
# Epoch 75/100

# %%
train_loss, train_accuracy = cnn_model.evaluate(train_generator, verbose=1)
print(f'Training accuracy: {train_accuracy:.4f}')

# Evaluate on the test data
test_loss, test_accuracy = cnn_model.evaluate(test_generator, verbose=1)
print(f'Test accuracy: {test_accuracy:.4f}')

# %%
# Retrieve metrics from the training history
acc = Cnn.history['accuracy']
val_acc = Cnn.history['val_accuracy']
loss = Cnn.history['loss']
val_loss = Cnn.history['val_loss']

epochs_range = range(1, len(acc) + 1)

# Plot accuracy
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy for CNN')
plt.legend()

# Plot loss
plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss for CNN')
plt.legend()

plt.tight_layout()
plt.show()
