# %% [markdown]
# <a href="https://colab.research.google.com/github/nimitha123-kd/Take-IT-Smart-Internship/blob/main/New_Session_TIS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **6/3/2026**
#
# **Theory Concepts by Jeevitha  Maam.**
#
# #1. What is a Data Scientist? 📊
#
# A Data Scientist is a person who studies data (information) to find useful insights and help organizations make better decisions.
#
# They:
#
# Collect data
#
# Clean and analyze data
#
# Use statistics and machine learning
#
# Present results using graphs or reports
#
#
# Example:
# A Netflix data scientist studies users’ watching history to recommend movies you might like.
#
#
#
# #2. What should a Junior Data Scientist be thorough with? 👨‍💻
#
# A Junior Data Scientist should know the basics of the following:
#
# 1. Programming
#
# Python (very important)
#
# Libraries like Pandas, NumPy, Matplotlib, Seaborn
#
#
# 2. Statistics & Mathematics
#
# Mean, median, mode
#
# Probability
#
# Correlation
#
# Linear algebra basics
#
#
# 3. Data Handling
#
# Data cleaning
#
# Data visualization
#
# Working with datasets
#
#
# 4. Machine Learning Basics
#
# Regression
#
# Classification
#
# Clustering
#
# Model evaluation
#
#
# 5. Databases
#
# Basic SQL queries
#
#
#
#
#
# #3. What is Machine Learning?
#
# Machine Learning (ML) is a part of Artificial Intelligence where computers learn from data and make predictions without being directly programmed.
#
# Instead of giving exact instructions, we give data, and the system learns patterns.
#
# Example:
#
# Email spam detection
#
# Movie recommendations
#
# Face recognition
#
#
#
#
#
# #4. Applications of Machine Learning
#
# Machine Learning is used in many fields:
#
# 1. Healthcare
#
# Disease prediction
#
# Medical image analysis
#
#
# 2. Finance
#
# Fraud detection
#
# Credit score prediction
#
#
# 3. E-commerce
#
# Product recommendations
#
# Customer behavior analysis
#
#
# 4. Transportation
#
# Self-driving cars
#
# Traffic prediction
#
#
# 5. Entertainment
#
# Movie and music recommendations
#
#
#
#
#
# #5. Important facts for Communication Skills
#
# Good communication skills are very important for data scientists.
#
# Key points:
#
# 1. Explain complex data in simple words
#
#
# 2. Present results clearly using charts and graphs
#
#
# 3. Listen carefully to business problems
#
#
# 4. Work well with teams
#
#
# 5. Write clear reports or presentations
#
#
#
# Example:
# A data scientist must explain their analysis to managers who may not know technical terms.
#
#
#
#  In short:
#
# Data Scientist → analyzes data to get insights
#
# Junior Data Scientist → needs Python, statistics, ML basics
#
# Machine Learning → computers learn from data
#
# Applications → healthcare, finance, e-commerce, etc.
#
# Communication skills → explain results clearly and work with teams

# %% [markdown]
#  === Continuation of 1st class ===
#
#
# # **What is Machine Learning?**
# Machine Learning is the branch of Artificial Intelligence which learns from past data/history and that knowledge is used to predict the related future.
#
# # **How do yuo expalin Machine Learning to 5 Years old child /Non tech obes ?**
# Scenarios:
# 1.  Father and Child goes to park to play.
# 2. All of sudden the child notices a tree for the first time.
# 3. Child will be curious and question his dad what it is ?
# 4. Now dad explains each & everything related to the tree.
# 5. Initially child was knowing nothing and learnt everything from dad. ==>This phase is called as thTraining Phase.
#
#
# Scene 2 ==>
#   1. Next both goes to shopping .
#   2. Onthe way the child sees the tree again  and notices it.
#   3. But this time instead of being curious , the child was able to recognize it is a tree.==> This Phase is callled as the Testing Phase.
#
#
#   **Therefore Same thing happens in Machine Learning.**
#
#
#
#   # **Application of ML in daily life**
#
#   1. Weather prediction.
#   2. Email
#     - Inbox
#     - Spam
#   3. Netflix
#     - Suggestions.
#
#   4. Facebook
#      - Photo tagging.
#   5. Facial Recognition.
#     - Phones
#     - Id proof
#   6. Google Map
#     - Redline in the Traffic
#   7. Youtube
#     - Recommendations.
#   8. Intagram
#   - Friend Suggestion
#
#   9. LinkedIn
#   10. Google
#     - Voice Assistants.
#     - Google Adds
#   11. Alexa /Siri
#   12. Chat GPT / gemini / Claude / perplexity.
#
#   13. Self Driving Car
#
#
#
#
#   # **Types of ML**
#   1. Supervised Learning.
#   2. Unsupervised Learning.
#   3. Semi Supervised.
#   4. Reinforcement.
#
#
#   # **EDA == > Exploratory Data Analysis **
#
#   1. Problem Statement.
#   2. Objectivies.
#   3. Load Libraries.
#   4. load Data.
#   5. Understanding the variables.
#   6. Basic Checks.
#   7. Data Cleaning.
#     - Missing Values
#     - Duplicates
#   8. EDA
#     - Univariate.
#     - Bi variate.
#     - multi Variate.
#     - Insights.
#   9. Conclusions

# %% [markdown]
# # ***7/3/26*** ==> Task 24
#
#  # **Types of ML**
#   1. Supervised Learning.
#   2. Unsupervised Learning.
#   3. Semi Supervised.
#   4. Reinforcement.
#
# SOME BASIC FACTORS.
#
# **Variables**
# Y = X
# X = Independent / Feature / input
# Y = Dependent / Target / output
#
# ** Labelled Data **
# Data which has both input(X)
# as well as the output(y)
#
# 🎄(input) ====> Christmas Tree(o/p)
#
# **Unlabelled Data**
# Data which has only input .
# Eg: Bastetful of Friuts.
#
#
# # ** 1. Supervised Learning**
# => Supervised learning requires the labelled data.
# => It requires both input as well output.
#
# ![Screenshot 2026-03-11 222219.png](data:image/png;base64,...)
#
# **Types of Supervised Learning**
# 1. Regression
# 2. Classification.
#
#
#   -- Continuous data : Numerical data which lies within certain range.
#
#   Eg: Height , weight , price , sales , Age.
#
#   -- Categorical data: Text Data /categories.
#   Eg: Diabetic / Non diabetic
#
#   Yes/ No
#
#   True / False
#
#   Ham / Spam
#
#   Cancer / Non Cancer
#
#
#   -- Discrete Data : Countable / whole Numbers.
#
#   Eg: 1 /0
#      0/1/2
#      Rating -- 1.2, 3,4,5
#
# # **Regression**
# => Regression comes under supervised Learning. i.e X & Y
# => Regression is used when data type of target variable is continuous.
# => Regression is used to predict continuos  target variable.
#
#
# Eg:Sales Prediction
#
# Student Marks Performance
#
# House Price Prediction
#
# Car Price predictions.
#
# Flight Price Predictions.
#
# **Regression algirithms**
#
# =>Linear Reg
# =>KNN Reg
# =>SVM Reg
# =>Decision Tree Reg
# => Random Forest Regression
# =>Gradient Boosting Reg
# =>XGBoost  Reg.
#
# **Classification**
#
# => It is used to predict the categories / Classes.
#
#
# Eg: 1. Diabetics Predictions
#       - Diabetic
#       - Non Diabetic
#
#     2. Email Classification
#        - Ham
#        - Spam
#
#     3. Cancer Prediction
#        - Cancer
#        - Non Cancer
#
#     4. Heart Attack Risk
#        - Yes / 1
#        - No/ 0
#
#
#
# **Classification Algorithms**
# 1. Logistic regression
# 2. KNN Classification
# 3. SVM Classification
# 4. Decision Tree Class
# 5. Random Forest Class
# 6. Gradient Boosting
# 7. XGBoost Classification.
#
# #**Unsupervised**
# =>It requires unlabelled data
# =>Data should have only input.
#
# ![Screenshot 2026-03-11 224634.png](data:image/png;base64,...)
#
# Eg: Basket of Fruits
#   - shape
#   - color
#   - size
#
# unsupervised is aslo known as clustering Algorithm which takes unlabelled and creates clusters / groups based on similarities.
#
#
# Eg: Market Full of Fruits & Mall Customers Segmentation.
#
#     - K Means algorithms.
#
# #**Reinforecement**
#
# => learning happens based on the rewards and punishments.
# => It will interact wih environment
# which focus on maintaaining the rewards.
#
# Eg: AI chess
#    - good Move
#
#    - wrong Move
#
# Eg: Self Driving cars.
#
# #**Semi Supervised**
# =>It requirs both labelled & unlabelled data.
# => Model will be trained on small amount of labelled data and that model will be used to make predictions related to unlabelled data.
#
# => used when labelled data is Expensive or time consuming.

# %% [markdown]
# #  ***9/3/26*** ==> Task 25
#
# # **LINEAR REGRESSION.**
#
# => It comes  under Supervised Learning.
#
# Supervised Learning  includes both x and y.
#
# It is used to predict the continuous target variable.
#
# #**What is Linear Regression?**
#
# Linear Regression is used to find the linear relation between dependent (y) and Independent variables(X) by drawing a straight line or best fit line.
#
# ![Screenshot 2026-03-11 232140.png](data:image/png;base64,...)
#
# !![Screenshot 2026-03-11 232243.png](data:image/png;base64,...)
#
# X ==> indepent
#
# Y==> Dependent
#
# m ==> Slope ==> dy/dx
#
# c ==> Y-intercepts.
#         - points Yaxis where  straight line begins
#
#
#
# **GOAL OF LINEAR REGRESSION**
#
# # Find a best fit line such that error should be minimum .
# # the difference b/w actual and predicted points should be minimum.
#
#
#
# **TYPES OF LINEAR REGRESSION.**
#
# * Simple Linear
#
# * Multi Linear.
#
#
# * Polynomial Linear.
#
#
#
# #SIMPLE LINEAR REGRESSION.
#
# Model requires single input (x) & single output(y).
# eq :  y=mx+c or y= beta not + beta not x
#
# Eg: Predict the marks based on the number of hours.
#
# # MULTI LINEAR
# Model requires Multiple input variables (x1,x2,x3....) & single output.
#
#
# y=m1x1+m2x2+m3x3+....+c
#
# Eg: Predicting House Price based on the sqarefeet , location, floors.
#
#
# #POLYNOMIAL REGRESSION.
# * used to find when there is no relation or non relational between
# dependent and independent variable.
#
# - Curve shape ==>
#
# Y = m1x1 + m2x2 + m3x3 +......+c
#
#
# # How Linear Regression works?
#
# ![Screenshot 2026-03-11 233911.png](data:image/png;base64,...)
#
# Assume there is a relationship b/w marks and number of hours studied.
# y=mx + c
#
# ![Screenshot 2026-03-11 235142.png](data:image/png;base64,...)

# %% [markdown]
# # **How do you say model is good ?**
#
# Compare actual value (y) and predicted value(y cap).
#
# Error or Loss = Atual Vlue - Predicted Value. E= y - y^
#
# it is the difference b/w actual & the predicted is called error.
#
# Regression loss funtions/ Matrices used in regression is far differ from the classification.
#
# 1. MSE (Mean squared Error)
# 2. MAE(Mean Absolute error)
# 3. RMSE(Root Mean Squared Error)
# 4. MAPE(Mean Absolute Percentage Error)
# 5.R^2
# 6.ADJUSTED R^2

# %% [markdown]
# # **HEALTH INSURANCE PREDICTION**

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# The goal of this project is to develop a predictive model that accurately estimates the medical insurance costs for individuals based on various demographic, lifestyle, and health-related factors. By applying machine learning techniques, we aim to assist insurance companies in better understanding their risk profiles and help individuals gain insights into how different factors influence their **insurance premiums**.

# %% [markdown]
# **Import Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **Load Data**

# %%
data =pd.read_csv('/content/insurance.csv')

# %%
data
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# # **Domain Analysis** The descriptions of the variables based on the insurance dataset:
#
# 1.**Age**
#
# **Description**: Age of the primary beneficiary covered by health insurance.
#
# **Type**: Continuous numerical variable.
#
# 2.**SexDescription**
#
# **Description**: Gender of the insurance contractor.
#
# **Type**: Categorical variable with **two levels**: female, male.
#
# 3.**BMI (Body Mass Index)**
#
# : Body mass index, which is a measure of body fat based on height and weight.
#
# **Type**: Continuous numerical variable.
# Ideal Range: Ideally between 18.5 to 24.9 kg/m².
#
# 4.**Children**
#
# **Description**: Number of children covered by health insurance or number of dependents.
#
# **Type**: Discrete numerical variable.
#
# 5.**Smoker**
#
# **Description**: Binary indicator if the beneficiary is a smoker.
#
# **Type**: Categorical variable with **two levels**: yes, no.
#
# 6.**Region**
#
# **Description**: The beneficiary's residential area in the US.
#
# **Type**: Categorical variable with
#
# **four levels**: northeast, southeast, southwest, northwest.
#
# 7.**Charges**
#
# **Description**: Individual medical costs billed by health insurance.
#
# Type: Continuous numerical variable.

# %% [markdown]
# # **Basic Checks**

# %%
# check no. of rows and columns
data.shape
# Out:
# (1338, 7)

# %% [markdown]
# **The dataset hass 1338 rows and 7 columns .**

# %%
# first 5 rows
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
# last 5 rows
data.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
# check info : memory usage
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
# print numercial columns
num_colms= data.select_dtypes(include=['int64','float64'])
print(num_colms)
# Out:
#       age     bmi  children      charges
# 0      19  27.900         0  16884.92400
# 1      18  33.770         1   1725.55230
# 2      28  33.000         3   4449.46200
# 3      33  22.705         0  21984.47061
# 4      32  28.880         0   3866.85520
# ...   ...     ...       ...          ...
# 1333   50  30.970         3  10600.54830
# 1334   18  31.920         0   2205.98080
# 1335   18  36.850         0   1629.83350
# 1336   21  25.800         0   2007.94500
# 1337   61  29.070         0  29141.36030
#
# [1338 rows x 4 columns]

# %%
# print only categorical columns
cat_colms= data.select_dtypes(include='object')
print(cat_colms)
# Out:
#          sex smoker     region
# 0     female    yes  southwest
# 1       male     no  southeast
# 2       male     no  southeast
# 3       male     no  northwest
# 4       male     no  northwest
# ...      ...    ...        ...
# 1333    male     no  northwest
# 1334  female     no  northeast
# 1335  female     no  southeast
# 1336  female     no  southwest
# 1337  female    yes  northwest
#
# [1338 rows x 3 columns]

# %%
# check data types  of each colums
data.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
#find the statistical report numercial data
data.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
# find statistical report of cayegorical data
data.describe(include ='object')
# Out:
#          sex smoker     region
# count   1338   1338       1338
# unique     2      2          4
# top     male     no  southeast
# freq     676   1064        364

# %%
# find unique / distinct values
for x in cat_colms:
    print(x,'--->',data[x].unique())
# Out:
# sex ---> ['female' 'male']
# smoker ---> ['yes' 'no']
# region ---> ['southwest' 'southeast' 'northwest' 'northeast']

# %%
# find valuecount of each
for x in cat_colms:
    print(data[x].value_counts())
    print()
# Out:
# sex
# male      676
# female    662
# Name: count, dtype: int64
#
# smoker
# no     1064
# yes     274
# Name: count, dtype: int64
#
# region
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: count, dtype: int64

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %% [markdown]
# # **11/3/2026**
#
# # **Data Cleaning**

# %% [markdown]
# ### Check for missing values and handle them

# %%
data.duplicated().sum()
# Out:
# np.int64(1)

# %%
# drop duplicates
data.drop_duplicates(inplace=True)

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # **Exploratory Data Analysis**

# %% [markdown]
# # **Univariate analysis**
# Analysing single variable / column
#
# - histogram
# - count plot
# - box plot

# %%
# check the distribution of age
plt.figure(figsize=(5,2))
sns.histplot(data,x='age',kde=True)
plt.show()

# %%
# check the distribution of bmi
plt.figure(figsize=(5,2))
sns.histplot(data,x='bmi',kde=True)
plt.show()

# %%
# check the distribution of charges
plt.figure(figsize=(5,2))
sns.histplot(data,x='charges',kde=True)
plt.show()

# %%
# Visualise count of male and female
plt.figure(figsize=(5,2))
sns.countplot(data,x='sex')
plt.show()

# %%
# Visualise count of smokers and non smoker
plt.figure(figsize=(5,2))
sns.countplot(data,x='smoker')
plt.show()

# %%
# Visualise count of region
plt.figure(figsize=(5,2))
sns.countplot(data,x='region')
plt.show()

# %%
# Visualise count of children
plt.figure(figsize=(5,2))
sns.countplot(data,x='children')
plt.show()

# %%
# check outliers in age
plt.figure(figsize=(5,2))
sns.boxplot(data,x='age')
plt.show()

# %%
# check outliers in bmi
plt.figure(figsize=(5,2))
sns.boxplot(data,x='bmi')
plt.show()

# %%
# check outliers in charges
plt.figure(figsize=(5,2))
sns.boxplot(data,x='charges')
plt.show()

# %% [markdown]
# ## **Bivariate Analysis**
# Analysing two variables/columns
# * Scatter
# * line
# * bar plot

# %%
# check the relationship between age and charges
plt.figure(figsize=(5,2))
sns.scatterplot(data,x='age',y='charges')
plt.show()

# %%
# check the relationship between bmi and charges
plt.figure(figsize=(5,2))
sns.scatterplot(data,x='bmi',y='charges')
plt.show()

# %%
# Compare how charges vary with gender
plt.figure(figsize=(5,2))
sns.barplot(data,x='sex',y='charges')
plt.show()

# %%
# compare how charges vary with smoker
plt.figure(figsize=(5,2))
sns.barplot(data,x='smoker',y='charges')
plt.show()

# %%
# compare how charges vary with region
plt.figure(figsize=(5,2))
sns.barplot(data,x='region',y='charges')
plt.show()

# %%
# compare how charges vary with children
plt.figure(figsize=(5,2))
sns.barplot(data,x='children',y='charges')
plt.show()

# %% [markdown]
# ***11/3/2026***
# # **Multivariate Analysis**

# %%
# pairplot: It creates scatter plot among all the numerical variables
sns.pairplot(data)

# %%
# heat map : Used to visualise the correlation
# Correlation measures how strong two variables

num_colms.corr()
# Out:
#                age       bmi  children   charges
# age       1.000000  0.109272  0.042469  0.299008
# bmi       0.109272  1.000000  0.012759  0.198341
# children  0.042469  0.012759  1.000000  0.067998
# charges   0.299008  0.198341  0.067998  1.000000

# %%
sns.heatmap(num_colms.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## **Handle Outliers**

# %% [markdown]
# Outliers are extreme values which are far away from actual data or range.
#
# Eg: Age of students : [20,21,22,23,24,98,100]
#
# In this 98 and 100 are outliers.

# %% [markdown]
# **Ways to Identify Outliers**
# - Box plot
# - Sactter plot
# - histogram

# %%
fig,ax = plt.subplots(1,3,figsize=(6,2))
sns.boxplot(data,x='age',ax=ax[0])
sns.boxplot(data,x='bmi',ax=ax[1])
sns.boxplot(data,x='charges',ax=ax[2])
plt.tight_layout()

# %% [markdown]
# There are outliers in bmi and charges towards right side.

# %% [markdown]
# **Find Outliers**
# 1. IQR(Inter quartile range): Used when data distribution is skewed.
# 2. 3-sigma rule : Used when data is normal
# 3. Outliers should handled only if % of outliers are less than 5%.

# %% [markdown]
# **Check the distibution of bmi and charges**

# %%
fig,ax=plt.subplots(1,2,figsize=(5,2))
sns.histplot(data,x='bmi',ax=ax[0],kde=True)
sns.histplot(data,x='charges',ax=ax[1],kde=True)
plt.tight_layout()

# %%
# find skew
data.loc[:,'bmi'].skew()
# Out:
# np.float64(0.28391419385321137)

# %%
data.loc[:,'charges'].skew()
# Out:
# np.float64(1.5153909108403483)

# %% [markdown]
# - BMI data distribution is normal.
# - Charges distribution is right skewed.

# %% [markdown]
# **IQR method for Charges**
#
# Data distribution is skewed
#
# 1. Find Q1
# 2. FInd Q3
# 3. IQR
# 4. lower_limit = Q1-1.5*IQR
# 5. upper_limit = Q3+ 1.5*IQR
# 6. If any value greater than upper limit or less than lower limit , we call them as outliers.

# %%
Q1 = data.loc[:,'charges'].quantile(0.25)
Q3 = data.loc[:,'charges'].quantile(0.75)
IQR = Q3-Q1
lower_limit = Q1 - 1.5 * IQR
upper_limit = Q3 + 1.5 * IQR

# %%
# filter all the values greater than upper_limit
data[data.loc[:,'charges']>upper_limit]
# Out:
#       age     sex     bmi  children smoker     region      charges
# 14     27    male  42.130         0    yes  southeast  39611.75770
# 19     30    male  35.300         0    yes  southwest  36837.46700
# 23     34  female  31.920         1    yes  northeast  37701.87680
# 29     31    male  36.300         2    yes  southwest  38711.00000
# 30     22    male  35.600         0    yes  southwest  35585.57600
# ...   ...     ...     ...       ...    ...        ...          ...
# 1300   45    male  30.360         0    yes  southeast  62592.87309
# 1301   62    male  30.875         3    yes  northwest  46718.16325
# 1303   43    male  27.800         0    yes  southwest  37829.72420
# 1313   19  female  34.700         2    yes  southwest  36397.57600
# 1323   42  female  40.370         2    yes  southeast  43896.37630
#
# [139 rows x 7 columns]

# %%
# filter values less than lower_limit
data[data.loc[:,'charges']<lower_limit]
# Out:
# Empty DataFrame
# Columns: [age, sex, bmi, children, smoker, region, charges]
# Index: []

# %%
# percentage of outliers
len(data[(data.loc[:,'charges']>upper_limit)|(data.loc[:,'charges']<lower_limit)
])/len(data)*100
# Out:
# 10.396409872849663

# %% [markdown]
# If it was less than 5% we could have replace with median.

# %% [markdown]
# **3 Sigma rule for Bmi**
#
# Data distribution of bmi is normal
#
# 1. Find mean
# 2. Find Standard deviation
# 3. lower limit = mean - 3* std
# 4. upper limit = mean + 3* std
# 5. Any value greater than upper limit or less than lower limit is considered as outlier.

# %%
mean_val= data.loc[:,'bmi'].mean()
std_val =data.loc[:,'bmi'].std()
lower_limit = mean_val - 3*std_val
upper_limit = mean_val + 3*std_val

# %%
# filter values greater than upper limit
data[data.loc[:,'bmi']>upper_limit]
# Out:
#       age   sex    bmi  children smoker     region     charges
# 116    58  male  49.06         0     no  southeast  11381.3254
# 847    23  male  50.38         1     no  southeast   2438.0552
# 1047   22  male  52.58         1    yes  southeast  44501.3982
# 1317   18  male  53.13         0     no  southeast   1163.4627

# %%
# filter values less than lower limit
data[data.loc[:,'bmi']<lower_limit]
# Out:
# Empty DataFrame
# Columns: [age, sex, bmi, children, smoker, region, charges]
# Index: []

# %%
# find %
len(data[(data.loc[:,'bmi']>upper_limit)|(data.loc[:,'bmi']<lower_limit)])/len(data)*100
# Out:
# 0.2991772625280479

# %% [markdown]
# since % of outliers is less than 5% we need to replace them with mean.

# %%
data.loc[data.loc[:,'bmi']>upper_limit,'bmi']= data.loc[:,'bmi'].mean()

# %%
data[data.loc[:,'bmi']>upper_limit]
# Out:
# Empty DataFrame
# Columns: [age, sex, bmi, children, smoker, region, charges]
# Index: []

# %% [markdown]
# ## **Encoding Techniques**
#
# The process of converting text to numerical so that machine can can understand.
#
# * Label Encoder
# * One hot Encoder
# * Ordinal Encoder
# * Target Encoder
# * Manual Encoder

# %% [markdown]
# # **Label Encoder**
# Label Encoder assigns unique numbers to text starting from 0 according to alphabetical order.

# %%
# Yes - 1
# No -0

# %%
# red - 2
# green - 1
# blue -0

# %%
# UG -2
# PHD - 1
# PG - 0

# male - 1
# female - 0

# Label Encoder doesn't work when order matters or priority matters.
# Use label Encoder when order doesn't matter or no priority issues.

# %% [markdown]
# Smoker
#
# Label Encoder

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data.loc[:,'Smoker']= le.fit_transform(data.loc[:,'smoker'])

# %%
# drop old smoker column
data.drop(columns='smoker',inplace=True)

# %%
data
# Out:
#       age     sex     bmi  children     region      charges  Smoker
# 0      19  female  27.900         0  southwest  16884.92400       1
# 1      18    male  33.770         1  southeast   1725.55230       0
# 2      28    male  33.000         3  southeast   4449.46200       0
# 3      33    male  22.705         0  northwest  21984.47061       0
# 4      32    male  28.880         0  northwest   3866.85520       0
# ...   ...     ...     ...       ...        ...          ...     ...
# 1333   50    male  30.970         3  northwest  10600.54830       0
# 1334   18  female  31.920         0  northeast   2205.98080       0
# 1335   18  female  36.850         0  southeast   1629.83350       0
# 1336   21  female  25.800         0  southwest   2007.94500       0
# 1337   61  female  29.070         0  northwest  29141.36030       1
#
# [1337 rows x 7 columns]

# %% [markdown]
# # ***12/3/2026***
# # One hot Encoding.
# Creates new columns according to categories and assign 1 if value exists else 0.

# %%
# Gender | male |female
# male   | 1    | 0
#female  | 0    | 1
#male    | 1    | 0
#female  |0     |1
#male    |1     |0


# used one hot when all categories should be treated equally
# avoid using when there are so many categories

# %%
#sex
# In Python, dummies usually refer to dummy variables, which are created to convert categorical data into numerical form so that machine learning models can understand it.
# In Machine Learning, most algorithms cannot work with text or categorical values like Male, Female, Red, Blue, etc. So we convert them into 0s and 1s using dummy variables.
data = pd.get_dummies(data,columns=['sex'],dtype='int')
data
# Out:
#       age     bmi  children     region      charges  Smoker  sex_female  \
# 0      19  27.900         0  southwest  16884.92400       1           1
# 1      18  33.770         1  southeast   1725.55230       0           0
# 2      28  33.000         3  southeast   4449.46200       0           0
# 3      33  22.705         0  northwest  21984.47061       0           0
# 4      32  28.880         0  northwest   3866.85520       0           0
# ...   ...     ...       ...        ...          ...     ...         ...
# 1333   50  30.970         3  northwest  10600.54830       0           0
# 1334   18  31.920         0  northeast   2205.98080       0           1
# 1335   18  36.850         0  southeast   1629.83350       0           1
# 1336   21  25.800         0  southwest   2007.94500       0           1
# 1337   61  29.070         0  northwest  29141.36030       1           1
#
#       sex_male
# 0            0
# 1            1
# 2            1
# 3            1
# 4            1
# ...

# %% [markdown]
# ## Manual Encoder
# Assign values manually based on priority.

# %%
# UG -0
#PG - 1
# PHD -2

# %% [markdown]
# ###Ordinal Encoder
# Assign values based on order/ranking

# %%
# high : 2
# average : 1
# low : 0

# %% [markdown]
# ###Target Encoding
# Assign values based on comparing column with the target column.

# %%
# region
plt.figure(figsize=(5,2))
sns.barplot(data,x='region',y='charges')
plt.show()

# %%
data.loc[:,"region"]=data.loc [:,'region'].map({'southwest':0,"northwest":1 ,"northeast":2,"southeast":3})

# %%
data.drop(columns='region',inplace=True)

# %%
data
# Out:
#       age     bmi  children      charges  Smoker  sex_female  sex_male
# 0      19  27.900         0  16884.92400       1           1         0
# 1      18  33.770         1   1725.55230       0           0         1
# 2      28  33.000         3   4449.46200       0           0         1
# 3      33  22.705         0  21984.47061       0           0         1
# 4      32  28.880         0   3866.85520       0           0         1
# ...   ...     ...       ...          ...     ...         ...       ...
# 1333   50  30.970         3  10600.54830       0           0         1
# 1334   18  31.920         0   2205.98080       0           1         0
# 1335   18  36.850         0   1629.83350       0           1         0
# 1336   21  25.800         0   2007.94500       0           1         0
# 1337   61  29.070         0  29141.36030       1           1         0
#
# [1337 rows x 7 columns]

# %% [markdown]
# ##**Scaling**
# If there is a huge variation among the values in different numerical column we use scaling to bring all the values to a same scale so that calculations becomes easy.
#  * Min max Scaler
#  * Standard Scaler
#
#  ###NOTE :
#  - Use one scaling method for a model.
#  using both doesnt make sense.
#  try both and fix that is suitable for that model.

# %% [markdown]
# # **MIN MAX SCALER**
# - it tansforms all the values into range of 0 to 1.![Screenshot 2026-03-12 162535.png](data:image/png;base64,...)

# %%
df = data.copy()
# creating a new variable , & copying the dataframe of variable data to it.
# or can say duplicating the dataframe to new variable.

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
data[['age']]= scaler.fit_transform(data[['age']])
data[['bmi']]= scaler.fit_transform(data[['bmi']])

# %%
data
# Out:
#            age       bmi  children      charges  Smoker  sex_female  sex_male
# 0     0.021739  0.371847         0  16884.92400       1           1         0
# 1     0.000000  0.554656         1   1725.55230       0           0         1
# 2     0.217391  0.530676         3   4449.46200       0           0         1
# 3     0.326087  0.210059         0  21984.47061       0           0         1
# 4     0.304348  0.402367         0   3866.85520       0           0         1
# ...        ...       ...       ...          ...     ...         ...       ...
# 1333  0.695652  0.467456         3  10600.54830       0           0         1
# 1334  0.000000  0.497041         0   2205.98080       0           1         0
# 1335  0.000000  0.650576         0   1629.83350       0           1         0
# 1336  0.065217  0.306447         0   2007.94500       0           1         0
# 1337  0.934783  0.408284         0  29141.36030       1           1         0
#
# [1337 rows x 7 columns]

# %% [markdown]
# # **STANDARD SCALER**
# - it transforms all the vlaues to the same scale so that mean of  column will be 0 and stdeviation  will be 1.
# ![Screenshot 2026-03-12 163250.png](data:image/png;base64,...)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df[['age']]= scaler.fit_transform(df[['age']])
df[['bmi']]= scaler.fit_transform(df[['bmi']])

# %%
df
# Out:
#            age       bmi  children      charges  Smoker  sex_female  sex_male
# 0    -1.440418 -0.450897         0  16884.92400       1           1         0
# 1    -1.511647  0.528752         1   1725.55230       0           0         1
# 2    -0.799350  0.400246         3   4449.46200       0           0         1
# 3    -0.443201 -1.317894         0  21984.47061       0           0         1
# 4    -0.514431 -0.287344         0   3866.85520       0           0         1
# ...        ...       ...       ...          ...     ...         ...       ...
# 1333  0.767704  0.061458         3  10600.54830       0           0         1
# 1334 -1.511647  0.220004         0   2205.98080       0           1         0
# 1335 -1.511647  1.042775         0   1629.83350       0           1         0
# 1336 -1.297958 -0.801367         0   2007.94500       0           1         0
# 1337  1.551231 -0.255635         0  29141.36030       1           1         0
#
# [1337 rows x 7 columns]

# %% [markdown]
# # **Log Transformation**
# - Usually applied on the target column only in the regression.
# - Uesd to transform adta into normal distribution.
#
# # ==>Why is this used?
# _Linear regression expects data distribution of target to be normal.

# %%
# CHARGES
plt.figure(figsize=(5,2))
sns.histplot(data, x='charges', kde = True)
plt.show()
# RIGHT Skewed.

# %%
data.loc[:,"charges"]=np.log(data.loc[:,"charges"])

# %%
plt.figure(figsize=(5,2))
sns.histplot(data, x='charges', kde = True)
plt.show()

# After using the log trasformation , the right skewd convert to normal distribution.

# %% [markdown]
# #  FEATURE ENGINEERING
# - Select best featues
# - drop the columns
# - create a new column

# %% [markdown]
# # Split data for x & y
#
# ![Screenshot 2026-03-12 170105.png](data:image/png;base64,...)
#
#
#
# ![Screenshot 2026-03-12 170213.png](data:image/png;base64,...)

# %%
x = data.drop(columns='charges')
y=data['charges']

# %% [markdown]
# # Split data for training and testing

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.shape
# Out:
# (1069, 6)

# %%
x_test.shape
# Out:
# (268, 6)

# %% [markdown]
# # Linear Regression
# [link text](https://drive.google.com/file/d/15BRnpGF-NNeMd2nKyBfbisoLm8PZ36SP/view?usp=sharing)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
#train model with x_train , y_train
model.fit(x_train,y_train)
#make predictions using x_test
y_pred= model.predict(x_test)

# %%
#slope
model.coef_
# Out:
# array([ 1.56684636,  0.37350681,  0.0997899 ,  1.53277895,  0.03628958,
#        -0.03628958])

# %%
#intercept
model.intercept_
# Out:
# np.float64(7.786877033166462)

# %% [markdown]
# # **Logistc Regression**
# - Confusion Matrix
# - precision
# - recall
# - roc_auc Score

# %%
from sklearn.metrics import confusion_matrix,accuracy_score, recall_score,precision_score, roc_auc_score

# %% [markdown]
# # Evalute the regression
# - the evalution step of regression is different from classification

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,mean_absolute_percentage_error

# %%
#mean squared error
mean_squared_error(y_test,y_pred)
# Out:
# 0.16603117264240627

# %%
#mean_absolute error
mean_absolute_error(y_test,y_pred)
# Out:
# 0.2686059193535882

# %%
# rmse
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# np.float64(0.40746922907430233)

# %%
# mape
mean_absolute_percentage_error(y_test,y_pred)
# Out:
# 0.02980450682285524

# %% [markdown]
# # **13/3/2026**
# # **R^2 Score and Adjusted R^2 Score**

# %% [markdown]
# R^2 Score :It is used to measur how good is amodel.
#
# - It just compares Regression model and average model to explain the variation.
#
# ![Screenshot 2026-03-14 221917.png](data:image/png;base64,...)
#
#
# ![Screenshot 2026-03-14 222014.png](data:image/png;base64,...)
#
# TSS => Total Sum of Squares.
#
# ![Screenshot 2026-03-14 222205.png](data:image/png;base64,...)![Screenshot 2026-03-14 222240.png](data:image/png;base64,...)

# %%
# r2 error
from sklearn.metrics import r2_score
r2 = r2_score(y_test,y_pred)
r2
# Out:
# 0.8211218056565466

# %%
# adjusted r2 _score
n = x_test.shape[0]
n
# Out:
# 268

# %%
# p : no of columns
p=x_test.shape[1]
p
# Out:
# 6

# %%
adj = 1-(1-r2) * (n-1)/(n-p-1)
adj
# Out:
# 0.8170096632578465

# %% [markdown]
# # KNN Regressor

# %%
from sklearn.neighbors import KNeighborsRegressor
model = KNeighborsRegressor(n_neighbors=5)
model.fit(x_train,y_train)
y_pred = model.predict(x_test)

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 0.14796278216893874

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 0.23514815709174677

# %%
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# np.float64(0.3846593066194275)

# %%
mean_absolute_percentage_error(y_test,y_pred)
# Out:
# 0.025901326874194327

# %%
r2 =r2_score(y_test,y_pred)
r2
# Out:
# 0.840588276989297

# %%
adj = 1 - (1-r2)*(n-1)/(n-p-1)
adj
# Out:
# 0.8369236396787061

# %% [markdown]
# # how to find K

# %%
error=[]
for k in range(2,11):
  model = KNeighborsRegressor(n_neighbors=k)
  model.fit(x_train,y_train)
  y_pred = model.predict(x_test)
  rmse = np.sqrt(mean_squared_error(y_test,y_pred))
  error.append(rmse)
print(error)
# Out:
# [np.float64(0.45195763726868815), np.float64(0.41241835549273115), np.float64(0.39478940280504277), np.float64(0.3846593066194275), np.float64(0.3832331337551614), np.float64(0.3882012604912477), np.float64(0.3908534569266615), np.float64(0.38868233095200677), np.float64(0.3867425790138307)]

# %%
plt.figure(figsize=(5,2))
plt.plot(range(2,11),error)
plt.xlabel('k')
plt.ylabel('error')
plt.show()

# %% [markdown]
# # **Regression Project**
# 1. Project Title
# 2. Problem Statement
# 3. Objective
# 4. Import libraries
# 5. Load data
# 6. Domain analysis/Understand variable
# 7. Basic checks
# 8. Data Cleaning : Missing values + Duplicates
# 9. EDA : Univariate,bivariate,multivariate
# 10. Handle outliers
# 11. Encoding
# 12. Scaling
# 13. Log transformation
# 14. Feature selection
# 15. Split data for x and y
# 16. Split data for training and testing
# 17. Implement the model
# 18. Evaluate the model
# 19. Final conclusion
# 20. FInal Deployment

# %% [markdown]
# 24/3/2026
# # Decison Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor
model=DecisionTreeRegressor()
model.fit(x_train,y_train)
y_pred = model.predict(x_test)

# %%
#evaluate the model
print("mse",mean_squared_error(y_test,y_pred))
print("mae",mean_absolute_error(y_test,y_pred))
print("rmse",np.sqrt(y_test,y_pred))
print("mape",mean_absolute_percentage_error(y_test,y_pred))
print("r2 score",r2_score(y_test,y_pred))
print("adjusted r2 score",1 - (1-r2)*(n-1)/(n-p-1))
# Out:
# mse 0.377249755677682
# mae 0.2765695581192539
# rmse 900     3.011610
# 1064    2.941050
# 1256    3.056892
# 298     3.250353
# 237     2.898900
#           ...
# 534     3.087827
# 542     3.088482
# 760     2.876685
# 1284    3.281228
# 1285    3.008636
# Name: charges, Length: 268, dtype: float64
# mape 0.6676887864812651
# r2 score -39.9848229992077
# adjusted r2 score 0.8369236396787061

# %%
from sklearn.tree import DecisionTreeRegressor
model=DecisionTreeRegressor(criterion='squared_error',max_depth=50,max_features='sqrt',splitter='best',min_samples_leaf=6,min_samples_split=5

                        )
model.fit(x_train,y_train)
y_pred = model.predict(x_test)

# %%
#evaluate the model
print("mse",mean_squared_error(y_test,y_pred))
print("mae",mean_absolute_error(y_test,y_pred))
print("rmse",np.sqrt(y_test,y_pred))
print("mape",mean_absolute_percentage_error(y_test,y_pred))
print("r2 score",r2_score(y_test,y_pred))
print("adjusted r2 score",1 - (1-r2)*(n-1)/(n-p-1))
# Out:
# mse 0.2351886050647753
# mae 0.32298812366694357
# rmse 900     3.011610
# 1064    2.941050
# 1256    3.056892
# 298     3.250353
# 237     2.898900
#           ...
# 534     3.087827
# 542     3.088482
# 760     2.876685
# 1284    3.281228
# 1285    3.008636
# Name: charges, Length: 268, dtype: float64
# mape 0.6676887864812651
# r2 score -39.9848229992077
# adjusted r2 score 0.8369236396787061

# %% [markdown]
# ***10/3/2026***
#
# Delt with other dataset on the same day.
# # **Data Analysis of New Dataset.**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
datta = pd.read_csv('/content/telecom_churn_data.csv')
datta
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %% [markdown]
# Check for missing values.

# %%
datta.isnull().sum()
# Out:
# customerID          0
# gender              5
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    2
# PaymentMethod       0
# MonthlyCharges      2
# TotalCharges        5
# Churn               0
# dtype: int64

# %% [markdown]
# # **How to handle missing values.**
#
# 1. Can we drop missing values .
# - we can drop missing values if there are few values missing.
# - Dropping missing is not recommended
# when huge values are missing as it results in loss of information.
# - Drop the column when % of missing values is greater than 70%.
# 2. Can we replace rhem with values
# - We can use domain knoweledge and replace.
# - We can replace witheither mean oe median or mode.
# 3. When to use mode.
# - Use mode when categorical /text data is missing.
# 4. When to use mean ir median.
# - use when missing values is numerical.
# - use mean when data distribution is  normal.
# - use meadian when data distribution is skewed(left/right skewed).

# %% [markdown]
# gender

# %%
#check the data type.
datta.loc[: , "gender"].dtype
# Out:
# dtype('O')

# %% [markdown]
# clearely data type  of gender ids object.

# %%
# If data type is object use mode
# find mode
datta.loc[:,"gender"].mode()[0]
# Out:
# 'Male'

# %%
#use fillna to replcae
datta.loc[:,"gender"]=datta.loc[:,"gender"].fillna(datta.loc[:,"gender"].mode()[0])

# %%
#check
datta.loc[:,"gender"].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **PaperlessBillling.**

# %%
#check the data type.
datta.loc[: , "PaperlessBilling"].dtype
# Out:
# dtype('O')

# %%
# If data type is object use mode
# find mode
datta.loc[:,"PaperlessBilling"].mode()[0]
# Out:
# 'Yes'

# %%
#use fillna to replcae
datta.loc[:,"PaperlessBilling"]=datta.loc[:,"PaperlessBilling"].fillna(datta.loc[:,"PaperlessBilling"].mode()[0])

# %%
#check
datta.loc[:,"PaperlessBilling"].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **MonthlyCharges**

# %%
#check the datatype
#check the data type.
datta.loc[: , "MonthlyCharges"].dtypes
# Out:
# dtype('float64')

# %%
#check the disatribution.
plt.figure(figsize=(10,5))
sns.histplot(datta,x='MonthlyCharges',kde=True)
plt.show()

# %%
# find skew
#skew : [-0.5,0.5]--> its normal
#skew > 0.5--> right skew
##skew < - 0.5--> left skew
datta.loc[:,"MonthlyCharges"].skew()
# Out:
# np.float64(-0.22028439456532767)

# %%
# The distribution is normal
#find mean
datta.loc[:,"MonthlyCharges"].mean()
# Out:
# np.float64(64.74958102542253)

# %%
# fill with mean
datta.loc[:,"MonthlyCharges"]=datta.loc[:,"MonthlyCharges"].fillna(datta.loc[:,"MonthlyCharges"].mean())

# %% [markdown]
# **TotalCharges.**

# %%
datta.loc[:,"TotalCharges"].dtype
# Out:
# dtype('O')

# %% [markdown]
# Data type of total cxharge is incorrect.
# Values within TotalCharges are numeri but data type is object which is wrong.
#
# **Type casting**
#
# Convert one data type into other format
#
# - **as_type** : Used to when column doesn't have missisng values
# - **pd.to_numeric** : Use this when column has missing values

# %%
datta.loc[:,'Total_Charges'] =pd.to_numeric(datta.loc[:,'TotalCharges'],errors='coerce')

# %%
datta.drop(columns='TotalCharges',inplace=True)

# %%
# check distribution
plt.figure(figsize=(5,2))
sns.histplot(datta,x='Total_Charges',kde=True)
plt.show()

# %%
# check skewness
datta.loc[:,"Total_Charges"].skew()
# Out:
# np.float64(0.9616058347613503)

# %%
#Distribution is right skewed
# find median
datta.loc[:,"Total_Charges"].median()
# Out:
# 1397.3

# %%
#fill with median
datta.loc[:,"Total_Charges"]=datta.loc[:,"Total_Charges"].fillna(datta.loc[:,"Total_Charges"].median())

# %%
data.isnull().sum()
# Out:
# age           0
# bmi           0
# children      0
# charges       0
# Smoker        0
# sex_female    0
# sex_male      0
# dtype: int64
